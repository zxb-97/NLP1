# %% [markdown]
# <a href="https://colab.research.google.com/github/zxb-97/NLP1/blob/main/NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import random as rand

def scrape_reviews(base_url, headers, max_pages=20):
    all_reviews = []
    for page in range(1, max_pages + 1): #Change here for scraping other pages
        print(f"Fetching page {page}")
        response = requests.get(base_url + f"&pageNumber={page}", headers=headers)
        if response.status_code != 200:
            print(f"Failed to fetch page {page}, status code: {response.status_code}")
            break

        soup = BeautifulSoup(response.text, 'lxml')
        review_elements = soup.select("div[data-hook='review']")

        if not review_elements:
            print(f"No reviews found on page {page}, stopping.")
            break

        for review in review_elements:
            r_author_element = review.select_one("span.a-profile-name")
            r_author = r_author_element.text.strip() if r_author_element else None

            r_rating_element = review.select_one("i.review-rating span.a-icon-alt")
            r_rating = r_rating_element.text.replace(" out of 5 stars", "") if r_rating_element else None

            r_title_element = review.select_one("a.review-title span")
            r_title = r_title_element.text.strip() if r_title_element else None

            r_content_element = review.select_one("span.review-text-content span")
            r_content = r_content_element.text.strip() if r_content_element else None

            r_date_element = review.select_one("span.review-date")
            r_date = r_date_element.text.strip() if r_date_element else None

            r_verified_element = review.select_one("span.a-declarative span.a-size-mini")
            r_verified = r_verified_element.text.strip() if r_verified_element else "Not Verified"

            review_data = {
                "author": r_author,
                "rating": r_rating,
                "title": r_title,
                "content": r_content,
                "date": r_date,
                "verified": r_verified
            }

            all_reviews.append(review_data)

        # To avoid hitting the server too frequently
        time.sleep(rand.uniform(5,10))

    return all_reviews

# Base URL of the Amazon product reviews page (without page number)
base_url = 'https://www.amazon.co.uk/Lenovo-ThinkPad-Windows-Professional-Renewed/product-reviews/B07CSSF72G/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=1'
custom_headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36'}

# Fetch all reviews
all_reviews = scrape_reviews(base_url, custom_headers, max_pages=20)
print(all_reviews); exit;
# Save reviews to a JSONL file
file_path = "thinkpad_reviews_1-20.jsonl"
with open(file_path, "w") as f:
    for review in all_reviews:
        json.dump(review, f)
        f.write("\n")

print(f"Total number of reviews fetched: {len(all_reviews)}")
print(f"Reviews saved to {file_path}")
# Out:
# Fetching page 1
# Fetching page 2
# Fetching page 3
# Fetching page 4
# Fetching page 5
# Fetching page 6
# Fetching page 7
# Fetching page 8
# Fetching page 9
# Fetching page 10
# Fetching page 11
# Fetching page 12
# Fetching page 13
# Fetching page 14
# Fetching page 15
# Fetching page 16
# Fetching page 17
# Fetching page 18
# Fetching page 19
# Fetching page 20
# [{'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker.  I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc.  I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device.  Not a scratch, no wear on the keys, screen looks perfect and mint condition.  Device was extremely clean and smelled fresh... I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc.  Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office.  Office was on there but a demo/online version where you then had to buy 365.  I’m still a 2010 bloke so easily booted that up and all running really quickly.  In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old.  Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage?  For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified'}, {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says). Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend  for a family member who may not be computer literate.', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified'}, {'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified'}, {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'This is a beautiful little laptop computer I am very pleased with it.  My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem.  Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included.  I accepted and we received the PC in as new condition and very well packaged two days later.  The computer is very compact and is in excellent to nearly new condition.  I am having to get used to a smaller keyboard but that also is no  ...
# Total number of reviews fetched: 200
# Reviews saved to thinkpad_reviews_1-20.jsonl

# %% [markdown]
# Load the Json

# %%
# !pip install -U -q "langchain" "transformers==4.31.0" "datasets==2.13.0" "peft==0.4.0" "accelerate==0.21.0" "bitsandbytes==0.41.3" "trl==0.4.7" "safetensors>=0.3.1"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.5/973.5 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 29.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 32.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 9.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 28.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 10.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 10.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 91.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 26.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.2/310.2 kB 37.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.4/124.4 kB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 17.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 73.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 17.9 MB/s eta 0:00:00

# %%
import json
from langchain.docstore.document import Document

def load_reviews(file_path):
    reviews = []
    with open(file_path, "r") as f:
        for line in f:
            reviews.append(json.loads(line))
    return reviews

# Load reviews from the file
file_path = "thinkpad_reviews_1-20.jsonl"
reviews = load_reviews(file_path)
print(f"Loaded {len(reviews)} reviews.")
# Out:
# Loaded 200 reviews.

# %% [markdown]
# Clean Up the Data

# %%
import re

def clean_text(text):
    if text:
        text = text.strip()  # Remove leading and trailing white spaces
        text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with a single space
    return text

def preprocess_reviews(reviews):
    cleaned_reviews = []
    for review in reviews:
        cleaned_review = {
            "author": clean_text(review.get("author", "")),
            "rating": clean_text(review.get("rating", "")),
            "title": clean_text(review.get("title", "")),
            "content": clean_text(review.get("content", "")),
            "date": clean_text(review.get("date", "")),
            "verified": clean_text(review.get("verified", "Not Verified"))
        }
        cleaned_reviews.append(cleaned_review)
    return cleaned_reviews

# Clean the reviews
cleaned_reviews = preprocess_reviews(reviews)
print(f"Cleaned {len(cleaned_reviews)} reviews.")
# Out:
# Cleaned 200 reviews.

# %% [markdown]
# Splitting Document into chunks

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# Define the splitter with the maximum chunk length
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size = 500, # the character length of the chunk
    chunk_overlap = 30, # the character length of the overlap between chunks
    length_function = len,  # the length function - in this case, character length (aka the python len() fn.)
    separators=[". ", ", ", " "]
)

def chunk_reviews(reviews):
    chunked_reviews = []
    for review in reviews:
        # Split the content into chunks using the CharacterTextSplitter
        content_chunks = text_splitter.split_text(review["content"])
        for i, chunk in enumerate(content_chunks):
            chunked_review = review.copy()
            chunked_review["content"] = chunk
            chunked_review["chunk_id"] = f"{review['author']}_{i}" #Unique id for each chunk should work better
            chunked_reviews.append(chunked_review)
    return chunked_reviews

# Split the reviews into chunks
chunked_reviews = chunk_reviews(cleaned_reviews)
print(f"Chunked reviews count: {len(chunked_reviews)}")
for i, chunk in enumerate(chunked_reviews): #Nicer print
    print(f"Chunk {i+1}:\n{chunk}\n")
# Out:
# Chunked reviews count: 380
# Chunk 1:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker. I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 2:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device. Not a scratch, no wear on the keys, screen looks perfect and mint condition. Device was extremely clean and smelled fresh..', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_1'}
#
# Chunk 3:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc. Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office. Office was on there but a demo/online version where you then had to buy 365. I’m still a 2010 bloke so easily booted that up and all running really quickly', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_2'}
#
# Chunk 4:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_3'}
#
# Chunk 5:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage? For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_4'}
#
# Chunk 6:
# {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says)', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_0'}
#
# Chunk 7:
# {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend for a family member who may not be computer literate.', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_1'}
#
# Chunk 8:
# {'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified', 'chunk_id': 'ronan burke_0'}
#
# Chunk 9:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'This is a beautiful little laptop computer I am very pleased with it. My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem. Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included. I accepted and we received the PC in as new condition and very well packaged two days later', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_0'}
#
# Chunk 10:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 11:
# {'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': "Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item.", 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 12:
# {'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Love my laptop works really well no issue', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 13:
# {'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Very good refurb, though the keyboard is USA configuration so get this checked out before buying if this is an issue. I found this out only after buying but the seller sorted the problem very quickly without affecting the warranty. This is a minor inconvenience as the £ sign is not readily available so if this is an issue just enquire before buying and get the seller to get a UK configured keyboard installed before shipping', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._0'}
#
# Chunk 14:
# {'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': '. Other than that the machine is fast, which is what I needed and for a refurb is in very good condition for the price. If you want something lighter and thinner this is not for you as the machine is sturdy and heavy but that is not a problem for me.', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._1'}
#
# Chunk 15:
# {'author': 'Pradeep Shokeen', 'rating': '1.0', 'title': '1.0 out of 5 stars', 'content': 'One of the worst laptop purchase, it comes with a Super Slow processing with a factory and a heavy weight.... It would not allow you any experience of laptop but a box defective refurbished electronic item, not at all recommended, check reviews before purchasing....', 'date': 'Reviewed in the United Kingdom on 20 January 2024', 'verified': 'Not Verified', 'chunk_id': 'Pradeep Shokeen_0'}
#
# Chunk 16:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': "I don't pretend to be a technophobe when it comes to computers so I will describe my user experience with the refurbished Lenovo ThinkTank T430.I think one of the biggest tests I could give it's computing power is by using the Photoshop image editing app, and it coped with the apps very well. The laptop loaded both lightroom and photoshop very quickly and the lag between me carrying out an edit on an image, and what appeared on the screen, was barely perceptible", 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_0'}
#
# Chunk 17:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': ". I was also impressed with the speed photos were moved from lightroom into photoshop for further editing. Again, the speed was very quick, taking only a few seconds to open up photoshop and 'dump' the photo I wanted to edit into the photoshop app. I should point out that I was using the very latest Lightroom and Photoshop apps.With the SSD hard drive being so small in modern terms and no traditional hard drive to back it up, I have had to get used to using the cloud to store documents etc", 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_1'}
#
# Chunk 18:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': '. and probably helped me to get into the 21st century of doing things like this.Although the Lenovo ThinkTank t430 is a few years old now (it was originally loaded with Windows 7, but now has Windows 10), the Photoshop editing tools showed me that this laptop is more than capable of dealing with the latest, power intensive apps that is out there. I was impressed.', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_2'}
#
# Chunk 19:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Thanks it’s been working for now as I am just doing basic stuff and my grandkids love to watch the old dvds on it and it’s good to listen to my old cd collectionThanks', 'date': 'Reviewed in the United Kingdom on 9 December 2023', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 20:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker. I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 21:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device. Not a scratch, no wear on the keys, screen looks perfect and mint condition. Device was extremely clean and smelled fresh..', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_1'}
#
# Chunk 22:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc. Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office. Office was on there but a demo/online version where you then had to buy 365. I’m still a 2010 bloke so easily booted that up and all running really quickly', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_2'}
#
# Chunk 23:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_3'}
#
# Chunk 24:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage? For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_4'}
#
# Chunk 25:
# {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says)', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_0'}
#
# Chunk 26:
# {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend for a family member who may not be computer literate.', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_1'}
#
# Chunk 27:
# {'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified', 'chunk_id': 'ronan burke_0'}
#
# Chunk 28:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'This is a beautiful little laptop computer I am very pleased with it. My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem. Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included. I accepted and we received the PC in as new condition and very well packaged two days later', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_0'}
#
# Chunk 29:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 30:
# {'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': "Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item.", 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 31:
# {'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Love my laptop works really well no issue', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 32:
# {'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Very good refurb, though the keyboard is USA configuration so get this checked out before buying if this is an issue. I found this out only after buying but the seller sorted the problem very quickly without affecting the warranty. This is a minor inconvenience as the £ sign is not readily available so if this is an issue just enquire before buying and get the seller to get a UK configured keyboard installed before shipping', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._0'}
#
# Chunk 33:
# {'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': '. Other than that the machine is fast, which is what I needed and for a refurb is in very good condition for the price. If you want something lighter and thinner this is not for you as the machine is sturdy and heavy but that is not a problem for me.', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._1'}
#
# Chunk 34:
# {'author': 'Pradeep Shokeen', 'rating': '1.0', 'title': '1.0 out of 5 stars', 'content': 'One of the worst laptop purchase, it comes with a Super Slow processing with a factory and a heavy weight.... It would not allow you any experience of laptop but a box defective refurbished electronic item, not at all recommended, check reviews before purchasing....', 'date': 'Reviewed in the United Kingdom on 20 January 2024', 'verified': 'Not Verified', 'chunk_id': 'Pradeep Shokeen_0'}
#
# Chunk 35:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': "I don't pretend to be a technophobe when it comes to computers so I will describe my user experience with the refurbished Lenovo ThinkTank T430.I think one of the biggest tests I could give it's computing power is by using the Photoshop image editing app, and it coped with the apps very well. The laptop loaded both lightroom and photoshop very quickly and the lag between me carrying out an edit on an image, and what appeared on the screen, was barely perceptible", 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_0'}
#
# Chunk 36:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': ". I was also impressed with the speed photos were moved from lightroom into photoshop for further editing. Again, the speed was very quick, taking only a few seconds to open up photoshop and 'dump' the photo I wanted to edit into the photoshop app. I should point out that I was using the very latest Lightroom and Photoshop apps.With the SSD hard drive being so small in modern terms and no traditional hard drive to back it up, I have had to get used to using the cloud to store documents etc", 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_1'}
#
# Chunk 37:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': '. and probably helped me to get into the 21st century of doing things like this.Although the Lenovo ThinkTank t430 is a few years old now (it was originally loaded with Windows 7, but now has Windows 10), the Photoshop editing tools showed me that this laptop is more than capable of dealing with the latest, power intensive apps that is out there. I was impressed.', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_2'}
#
# Chunk 38:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Thanks it’s been working for now as I am just doing basic stuff and my grandkids love to watch the old dvds on it and it’s good to listen to my old cd collectionThanks', 'date': 'Reviewed in the United Kingdom on 9 December 2023', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 39:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker. I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 40:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device. Not a scratch, no wear on the keys, screen looks perfect and mint condition. Device was extremely clean and smelled fresh..', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_1'}
#
# Chunk 41:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc. Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office. Office was on there but a demo/online version where you then had to buy 365. I’m still a 2010 bloke so easily booted that up and all running really quickly', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_2'}
#
# Chunk 42:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_3'}
#
# Chunk 43:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage? For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_4'}
#
# Chunk 44:
# {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says)', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_0'}
#
# Chunk 45:
# {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend for a family member who may not be computer literate.', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_1'}
#
# Chunk 46:
# {'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified', 'chunk_id': 'ronan burke_0'}
#
# Chunk 47:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'This is a beautiful little laptop computer I am very pleased with it. My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem. Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included. I accepted and we received the PC in as new condition and very well packaged two days later', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_0'}
#
# Chunk 48:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 49:
# {'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': "Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item.", 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 50:
# {'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Love my laptop works really well no issue', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 51:
# {'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Very good refurb, though the keyboard is USA configuration so get this checked out before buying if this is an issue. I found this out only after buying but the seller sorted the problem very quickly without affecting the warranty. This is a minor inconvenience as the £ sign is not readily available so if this is an issue just enquire before buying and get the seller to get a UK configured keyboard installed before shipping', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._0'}
#
# Chunk 52:
# {'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': '. Other than that the machine is fast, which is what I needed and for a refurb is in very good condition for the price. If you want something lighter and thinner this is not for you as the machine is sturdy and heavy but that is not a problem for me.', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._1'}
#
# Chunk 53:
# {'author': 'Pradeep Shokeen', 'rating': '1.0', 'title': '1.0 out of 5 stars', 'content': 'One of the worst laptop purchase, it comes with a Super Slow processing with a factory and a heavy weight.... It would not allow you any experience of laptop but a box defective refurbished electronic item, not at all recommended, check reviews before purchasing....', 'date': 'Reviewed in the United Kingdom on 20 January 2024', 'verified': 'Not Verified', 'chunk_id': 'Pradeep Shokeen_0'}
#
# Chunk 54:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': "I don't pretend to be a technophobe when it comes to computers so I will describe my user experience with the refurbished Lenovo ThinkTank T430.I think one of the biggest tests I could give it's computing power is by using the Photoshop image editing app, and it coped with the apps very well. The laptop loaded both lightroom and photoshop very quickly and the lag between me carrying out an edit on an image, and what appeared on the screen, was barely perceptible", 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_0'}
#
# Chunk 55:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': ". I was also impressed with the speed photos were moved from lightroom into photoshop for further editing. Again, the speed was very quick, taking only a few seconds to open up photoshop and 'dump' the photo I wanted to edit into the photoshop app. I should point out that I was using the very latest Lightroom and Photoshop apps.With the SSD hard drive being so small in modern terms and no traditional hard drive to back it up, I have had to get used to using the cloud to store documents etc", 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_1'}
#
# Chunk 56:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': '. and probably helped me to get into the 21st century of doing things like this.Although the Lenovo ThinkTank t430 is a few years old now (it was originally loaded with Windows 7, but now has Windows 10), the Photoshop editing tools showed me that this laptop is more than capable of dealing with the latest, power intensive apps that is out there. I was impressed.', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_2'}
#
# Chunk 57:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Thanks it’s been working for now as I am just doing basic stuff and my grandkids love to watch the old dvds on it and it’s good to listen to my old cd collectionThanks', 'date': 'Reviewed in the United Kingdom on 9 December 2023', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 58:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker. I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 59:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device. Not a scratch, no wear on the keys, screen looks perfect and mint condition. Device was extremely clean and smelled fresh..', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_1'}
#
# Chunk 60:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc. Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office. Office was on there but a demo/online version where you then had to buy 365. I’m still a 2010 bloke so easily booted that up and all running really quickly', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_2'}
#
# Chunk 61:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_3'}
#
# Chunk 62:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage? For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_4'}
#
# Chunk 63:
# {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says)', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_0'}
#
# Chunk 64:
# {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend for a family member who may not be computer literate.', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_1'}
#
# Chunk 65:
# {'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified', 'chunk_id': 'ronan burke_0'}
#
# Chunk 66:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'This is a beautiful little laptop computer I am very pleased with it. My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem. Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included. I accepted and we received the PC in as new condition and very well packaged two days later', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_0'}
#
# Chunk 67:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 68:
# {'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': "Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item.", 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 69:
# {'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Love my laptop works really well no issue', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 70:
# {'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Very good refurb, though the keyboard is USA configuration so get this checked out before buying if this is an issue. I found this out only after buying but the seller sorted the problem very quickly without affecting the warranty. This is a minor inconvenience as the £ sign is not readily available so if this is an issue just enquire before buying and get the seller to get a UK configured keyboard installed before shipping', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._0'}
#
# Chunk 71:
# {'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': '. Other than that the machine is fast, which is what I needed and for a refurb is in very good condition for the price. If you want something lighter and thinner this is not for you as the machine is sturdy and heavy but that is not a problem for me.', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._1'}
#
# Chunk 72:
# {'author': 'Pradeep Shokeen', 'rating': '1.0', 'title': '1.0 out of 5 stars', 'content': 'One of the worst laptop purchase, it comes with a Super Slow processing with a factory and a heavy weight.... It would not allow you any experience of laptop but a box defective refurbished electronic item, not at all recommended, check reviews before purchasing....', 'date': 'Reviewed in the United Kingdom on 20 January 2024', 'verified': 'Not Verified', 'chunk_id': 'Pradeep Shokeen_0'}
#
# Chunk 73:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': "I don't pretend to be a technophobe when it comes to computers so I will describe my user experience with the refurbished Lenovo ThinkTank T430.I think one of the biggest tests I could give it's computing power is by using the Photoshop image editing app, and it coped with the apps very well. The laptop loaded both lightroom and photoshop very quickly and the lag between me carrying out an edit on an image, and what appeared on the screen, was barely perceptible", 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_0'}
#
# Chunk 74:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': ". I was also impressed with the speed photos were moved from lightroom into photoshop for further editing. Again, the speed was very quick, taking only a few seconds to open up photoshop and 'dump' the photo I wanted to edit into the photoshop app. I should point out that I was using the very latest Lightroom and Photoshop apps.With the SSD hard drive being so small in modern terms and no traditional hard drive to back it up, I have had to get used to using the cloud to store documents etc", 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_1'}
#
# Chunk 75:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': '. and probably helped me to get into the 21st century of doing things like this.Although the Lenovo ThinkTank t430 is a few years old now (it was originally loaded with Windows 7, but now has Windows 10), the Photoshop editing tools showed me that this laptop is more than capable of dealing with the latest, power intensive apps that is out there. I was impressed.', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_2'}
#
# Chunk 76:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Thanks it’s been working for now as I am just doing basic stuff and my grandkids love to watch the old dvds on it and it’s good to listen to my old cd collectionThanks', 'date': 'Reviewed in the United Kingdom on 9 December 2023', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 77:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker. I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 78:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device. Not a scratch, no wear on the keys, screen looks perfect and mint condition. Device was extremely clean and smelled fresh..', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_1'}
#
# Chunk 79:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc. Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office. Office was on there but a demo/online version where you then had to buy 365. I’m still a 2010 bloke so easily booted that up and all running really quickly', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_2'}
#
# Chunk 80:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_3'}
#
# Chunk 81:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage? For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_4'}
#
# Chunk 82:
# {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says)', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_0'}
#
# Chunk 83:
# {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend for a family member who may not be computer literate.', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_1'}
#
# Chunk 84:
# {'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified', 'chunk_id': 'ronan burke_0'}
#
# Chunk 85:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'This is a beautiful little laptop computer I am very pleased with it. My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem. Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included. I accepted and we received the PC in as new condition and very well packaged two days later', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_0'}
#
# Chunk 86:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 87:
# {'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': "Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item.", 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 88:
# {'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Love my laptop works really well no issue', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 89:
# ...
#
# Chunk 352:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 353:
# {'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': "Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item.", 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 354:
# {'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Love my laptop works really well no issue', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 355:
# {'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Very good refurb, though the keyboard is USA configuration so get this checked out before buying if this is an issue. I found this out only after buying but the seller sorted the problem very quickly without affecting the warranty. This is a minor inconvenience as the £ sign is not readily available so if this is an issue just enquire before buying and get the seller to get a UK configured keyboard installed before shipping', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._0'}
#
# Chunk 356:
# {'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': '. Other than that the machine is fast, which is what I needed and for a refurb is in very good condition for the price. If you want something lighter and thinner this is not for you as the machine is sturdy and heavy but that is not a problem for me.', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._1'}
#
# Chunk 357:
# {'author': 'Pradeep Shokeen', 'rating': '1.0', 'title': '1.0 out of 5 stars', 'content': 'One of the worst laptop purchase, it comes with a Super Slow processing with a factory and a heavy weight.... It would not allow you any experience of laptop but a box defective refurbished electronic item, not at all recommended, check reviews before purchasing....', 'date': 'Reviewed in the United Kingdom on 20 January 2024', 'verified': 'Not Verified', 'chunk_id': 'Pradeep Shokeen_0'}
#
# Chunk 358:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': "I don't pretend to be a technophobe when it comes to computers so I will describe my user experience with the refurbished Lenovo ThinkTank T430.I think one of the biggest tests I could give it's computing power is by using the Photoshop image editing app, and it coped with the apps very well. The laptop loaded both lightroom and photoshop very quickly and the lag between me carrying out an edit on an image, and what appeared on the screen, was barely perceptible", 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_0'}
#
# Chunk 359:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': ". I was also impressed with the speed photos were moved from lightroom into photoshop for further editing. Again, the speed was very quick, taking only a few seconds to open up photoshop and 'dump' the photo I wanted to edit into the photoshop app. I should point out that I was using the very latest Lightroom and Photoshop apps.With the SSD hard drive being so small in modern terms and no traditional hard drive to back it up, I have had to get used to using the cloud to store documents etc", 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_1'}
#
# Chunk 360:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': '. and probably helped me to get into the 21st century of doing things like this.Although the Lenovo ThinkTank t430 is a few years old now (it was originally loaded with Windows 7, but now has Windows 10), the Photoshop editing tools showed me that this laptop is more than capable of dealing with the latest, power intensive apps that is out there. I was impressed.', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_2'}
#
# Chunk 361:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Thanks it’s been working for now as I am just doing basic stuff and my grandkids love to watch the old dvds on it and it’s good to listen to my old cd collectionThanks', 'date': 'Reviewed in the United Kingdom on 9 December 2023', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 362:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker. I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 363:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device. Not a scratch, no wear on the keys, screen looks perfect and mint condition. Device was extremely clean and smelled fresh..', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_1'}
#
# Chunk 364:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc. Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office. Office was on there but a demo/online version where you then had to buy 365. I’m still a 2010 bloke so easily booted that up and all running really quickly', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_2'}
#
# Chunk 365:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_3'}
#
# Chunk 366:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage? For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_4'}
#
# Chunk 367:
# {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says)', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_0'}
#
# Chunk 368:
# {'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend for a family member who may not be computer literate.', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_1'}
#
# Chunk 369:
# {'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified', 'chunk_id': 'ronan burke_0'}
#
# Chunk 370:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'This is a beautiful little laptop computer I am very pleased with it. My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem. Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included. I accepted and we received the PC in as new condition and very well packaged two days later', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_0'}
#
# Chunk 371:
# {'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': '. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 372:
# {'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': "Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item.", 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 373:
# {'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Love my laptop works really well no issue', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 374:
# {'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': 'Very good refurb, though the keyboard is USA configuration so get this checked out before buying if this is an issue. I found this out only after buying but the seller sorted the problem very quickly without affecting the warranty. This is a minor inconvenience as the £ sign is not readily available so if this is an issue just enquire before buying and get the seller to get a UK configured keyboard installed before shipping', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._0'}
#
# Chunk 375:
# {'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': '. Other than that the machine is fast, which is what I needed and for a refurb is in very good condition for the price. If you want something lighter and thinner this is not for you as the machine is sturdy and heavy but that is not a problem for me.', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._1'}
#
# Chunk 376:
# {'author': 'Pradeep Shokeen', 'rating': '1.0', 'title': '1.0 out of 5 stars', 'content': 'One of the worst laptop purchase, it comes with a Super Slow processing with a factory and a heavy weight.... It would not allow you any experience of laptop but a box defective refurbished electronic item, not at all recommended, check reviews before purchasing....', 'date': 'Reviewed in the United Kingdom on 20 January 2024', 'verified': 'Not Verified', 'chunk_id': 'Pradeep Shokeen_0'}
#
# Chunk 377:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': "I don't pretend to be a technophobe when it comes to computers so I will describe my user experience with the refurbished Lenovo ThinkTank T430.I think one of the biggest tests I could give it's computing power is by using the Photoshop image editing app, and it coped with the apps very well. The laptop loaded both lightroom and photoshop very quickly and the lag between me carrying out an edit on an image, and what appeared on the screen, was barely perceptible", 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_0'}
#
# Chunk 378:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': ". I was also impressed with the speed photos were moved from lightroom into photoshop for further editing. Again, the speed was very quick, taking only a few seconds to open up photoshop and 'dump' the photo I wanted to edit into the photoshop app. I should point out that I was using the very latest Lightroom and Photoshop apps.With the SSD hard drive being so small in modern terms and no traditional hard drive to back it up, I have had to get used to using the cloud to store documents etc", 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_1'}
#
# Chunk 379:
# {'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'content': '. and probably helped me to get into the 21st century of doing things like this.Although the Lenovo ThinkTank t430 is a few years old now (it was originally loaded with Windows 7, but now has Windows 10), the Photoshop editing tools showed me that this laptop is more than capable of dealing with the latest, power intensive apps that is out there. I was impressed.', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_2'}
#
# Chunk 380:
# {'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'content': 'Thanks it’s been working for now as I am just doing basic stuff and my grandkids love to watch the old dvds on it and it’s good to listen to my old cd collectionThanks', 'date': 'Reviewed in the United Kingdom on 9 December 2023', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}

# %%
from langchain.docstore.document import Document
import pandas as pd

def create_documents(chunked_reviews):
    documents = []
    for review in chunked_reviews:
        metadata = {
            "author": review["author"],
            "rating": review["rating"],
            "title": review["title"],
            "date": review["date"],
            "verified": review["verified"],
            "chunk_id": review["chunk_id"]
        }
        document = Document(
            page_content=review["content"],
            metadata=metadata
        )
        documents.append(document)
    return documents

# Create documents from chunked reviews
documents = create_documents(chunked_reviews)
print(f"Created {len(documents)} documents.")
for i, doc in enumerate(documents): #Nicer print
    print(f"Chunk {i+1}:\n{doc}\n")
# Out:
# Created 380 documents.
# Chunk 1:
# page_content='Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker. I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 2:
# page_content='. I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device. Not a scratch, no wear on the keys, screen looks perfect and mint condition. Device was extremely clean and smelled fresh..' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_1'}
#
# Chunk 3:
# page_content='. I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc. Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office. Office was on there but a demo/online version where you then had to buy 365. I’m still a 2010 bloke so easily booted that up and all running really quickly' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_2'}
#
# Chunk 4:
# page_content='. In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_3'}
#
# Chunk 5:
# page_content='. Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage? For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_4'}
#
# Chunk 6:
# page_content='I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says)' metadata={'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_0'}
#
# Chunk 7:
# page_content='. Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend for a family member who may not be computer literate.' metadata={'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_1'}
#
# Chunk 8:
# page_content='Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.' metadata={'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified', 'chunk_id': 'ronan burke_0'}
#
# Chunk 9:
# page_content='This is a beautiful little laptop computer I am very pleased with it. My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem. Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included. I accepted and we received the PC in as new condition and very well packaged two days later' metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_0'}
#
# Chunk 10:
# page_content='. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.' metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 11:
# page_content="Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item." metadata={'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 12:
# page_content='Love my laptop works really well no issue' metadata={'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 13:
# page_content='Very good refurb, though the keyboard is USA configuration so get this checked out before buying if this is an issue. I found this out only after buying but the seller sorted the problem very quickly without affecting the warranty. This is a minor inconvenience as the £ sign is not readily available so if this is an issue just enquire before buying and get the seller to get a UK configured keyboard installed before shipping' metadata={'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._0'}
#
# Chunk 14:
# page_content='. Other than that the machine is fast, which is what I needed and for a refurb is in very good condition for the price. If you want something lighter and thinner this is not for you as the machine is sturdy and heavy but that is not a problem for me.' metadata={'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._1'}
#
# Chunk 15:
# page_content='One of the worst laptop purchase, it comes with a Super Slow processing with a factory and a heavy weight.... It would not allow you any experience of laptop but a box defective refurbished electronic item, not at all recommended, check reviews before purchasing....' metadata={'author': 'Pradeep Shokeen', 'rating': '1.0', 'title': '1.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 January 2024', 'verified': 'Not Verified', 'chunk_id': 'Pradeep Shokeen_0'}
#
# Chunk 16:
# page_content="I don't pretend to be a technophobe when it comes to computers so I will describe my user experience with the refurbished Lenovo ThinkTank T430.I think one of the biggest tests I could give it's computing power is by using the Photoshop image editing app, and it coped with the apps very well. The laptop loaded both lightroom and photoshop very quickly and the lag between me carrying out an edit on an image, and what appeared on the screen, was barely perceptible" metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_0'}
#
# Chunk 17:
# page_content=". I was also impressed with the speed photos were moved from lightroom into photoshop for further editing. Again, the speed was very quick, taking only a few seconds to open up photoshop and 'dump' the photo I wanted to edit into the photoshop app. I should point out that I was using the very latest Lightroom and Photoshop apps.With the SSD hard drive being so small in modern terms and no traditional hard drive to back it up, I have had to get used to using the cloud to store documents etc" metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_1'}
#
# Chunk 18:
# page_content='. and probably helped me to get into the 21st century of doing things like this.Although the Lenovo ThinkTank t430 is a few years old now (it was originally loaded with Windows 7, but now has Windows 10), the Photoshop editing tools showed me that this laptop is more than capable of dealing with the latest, power intensive apps that is out there. I was impressed.' metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_2'}
#
# Chunk 19:
# page_content='Thanks it’s been working for now as I am just doing basic stuff and my grandkids love to watch the old dvds on it and it’s good to listen to my old cd collectionThanks' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 9 December 2023', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 20:
# page_content='Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker. I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 21:
# page_content='. I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device. Not a scratch, no wear on the keys, screen looks perfect and mint condition. Device was extremely clean and smelled fresh..' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_1'}
#
# Chunk 22:
# page_content='. I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc. Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office. Office was on there but a demo/online version where you then had to buy 365. I’m still a 2010 bloke so easily booted that up and all running really quickly' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_2'}
#
# Chunk 23:
# page_content='. In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_3'}
#
# Chunk 24:
# page_content='. Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage? For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_4'}
#
# Chunk 25:
# page_content='I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says)' metadata={'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_0'}
#
# Chunk 26:
# page_content='. Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend for a family member who may not be computer literate.' metadata={'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_1'}
#
# Chunk 27:
# page_content='Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.' metadata={'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified', 'chunk_id': 'ronan burke_0'}
#
# Chunk 28:
# page_content='This is a beautiful little laptop computer I am very pleased with it. My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem. Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included. I accepted and we received the PC in as new condition and very well packaged two days later' metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_0'}
#
# Chunk 29:
# page_content='. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.' metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 30:
# page_content="Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item." metadata={'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 31:
# page_content='Love my laptop works really well no issue' metadata={'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 32:
# page_content='Very good refurb, though the keyboard is USA configuration so get this checked out before buying if this is an issue. I found this out only after buying but the seller sorted the problem very quickly without affecting the warranty. This is a minor inconvenience as the £ sign is not readily available so if this is an issue just enquire before buying and get the seller to get a UK configured keyboard installed before shipping' metadata={'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._0'}
#
# Chunk 33:
# page_content='. Other than that the machine is fast, which is what I needed and for a refurb is in very good condition for the price. If you want something lighter and thinner this is not for you as the machine is sturdy and heavy but that is not a problem for me.' metadata={'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._1'}
#
# Chunk 34:
# page_content='One of the worst laptop purchase, it comes with a Super Slow processing with a factory and a heavy weight.... It would not allow you any experience of laptop but a box defective refurbished electronic item, not at all recommended, check reviews before purchasing....' metadata={'author': 'Pradeep Shokeen', 'rating': '1.0', 'title': '1.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 January 2024', 'verified': 'Not Verified', 'chunk_id': 'Pradeep Shokeen_0'}
#
# Chunk 35:
# page_content="I don't pretend to be a technophobe when it comes to computers so I will describe my user experience with the refurbished Lenovo ThinkTank T430.I think one of the biggest tests I could give it's computing power is by using the Photoshop image editing app, and it coped with the apps very well. The laptop loaded both lightroom and photoshop very quickly and the lag between me carrying out an edit on an image, and what appeared on the screen, was barely perceptible" metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_0'}
#
# Chunk 36:
# page_content=". I was also impressed with the speed photos were moved from lightroom into photoshop for further editing. Again, the speed was very quick, taking only a few seconds to open up photoshop and 'dump' the photo I wanted to edit into the photoshop app. I should point out that I was using the very latest Lightroom and Photoshop apps.With the SSD hard drive being so small in modern terms and no traditional hard drive to back it up, I have had to get used to using the cloud to store documents etc" metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_1'}
#
# Chunk 37:
# page_content='. and probably helped me to get into the 21st century of doing things like this.Although the Lenovo ThinkTank t430 is a few years old now (it was originally loaded with Windows 7, but now has Windows 10), the Photoshop editing tools showed me that this laptop is more than capable of dealing with the latest, power intensive apps that is out there. I was impressed.' metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_2'}
#
# Chunk 38:
# page_content='Thanks it’s been working for now as I am just doing basic stuff and my grandkids love to watch the old dvds on it and it’s good to listen to my old cd collectionThanks' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 9 December 2023', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 39:
# page_content='Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker. I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 40:
# page_content='. I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device. Not a scratch, no wear on the keys, screen looks perfect and mint condition. Device was extremely clean and smelled fresh..' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_1'}
#
# Chunk 41:
# page_content='. I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc. Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office. Office was on there but a demo/online version where you then had to buy 365. I’m still a 2010 bloke so easily booted that up and all running really quickly' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_2'}
#
# Chunk 42:
# page_content='. In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_3'}
#
# Chunk 43:
# page_content='. Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage? For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_4'}
#
# Chunk 44:
# page_content='I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says)' metadata={'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_0'}
#
# Chunk 45:
# page_content='. Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend for a family member who may not be computer literate.' metadata={'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_1'}
#
# Chunk 46:
# page_content='Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.' metadata={'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified', 'chunk_id': 'ronan burke_0'}
#
# Chunk 47:
# page_content='This is a beautiful little laptop computer I am very pleased with it. My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem. Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included. I accepted and we received the PC in as new condition and very well packaged two days later' metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_0'}
#
# Chunk 48:
# page_content='. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.' metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 49:
# page_content="Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item." metadata={'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 50:
# page_content='Love my laptop works really well no issue' metadata={'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 51:
# page_content='Very good refurb, though the keyboard is USA configuration so get this checked out before buying if this is an issue. I found this out only after buying but the seller sorted the problem very quickly without affecting the warranty. This is a minor inconvenience as the £ sign is not readily available so if this is an issue just enquire before buying and get the seller to get a UK configured keyboard installed before shipping' metadata={'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._0'}
#
# Chunk 52:
# page_content='. Other than that the machine is fast, which is what I needed and for a refurb is in very good condition for the price. If you want something lighter and thinner this is not for you as the machine is sturdy and heavy but that is not a problem for me.' metadata={'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._1'}
#
# Chunk 53:
# page_content='One of the worst laptop purchase, it comes with a Super Slow processing with a factory and a heavy weight.... It would not allow you any experience of laptop but a box defective refurbished electronic item, not at all recommended, check reviews before purchasing....' metadata={'author': 'Pradeep Shokeen', 'rating': '1.0', 'title': '1.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 January 2024', 'verified': 'Not Verified', 'chunk_id': 'Pradeep Shokeen_0'}
#
# Chunk 54:
# page_content="I don't pretend to be a technophobe when it comes to computers so I will describe my user experience with the refurbished Lenovo ThinkTank T430.I think one of the biggest tests I could give it's computing power is by using the Photoshop image editing app, and it coped with the apps very well. The laptop loaded both lightroom and photoshop very quickly and the lag between me carrying out an edit on an image, and what appeared on the screen, was barely perceptible" metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_0'}
#
# Chunk 55:
# page_content=". I was also impressed with the speed photos were moved from lightroom into photoshop for further editing. Again, the speed was very quick, taking only a few seconds to open up photoshop and 'dump' the photo I wanted to edit into the photoshop app. I should point out that I was using the very latest Lightroom and Photoshop apps.With the SSD hard drive being so small in modern terms and no traditional hard drive to back it up, I have had to get used to using the cloud to store documents etc" metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_1'}
#
# Chunk 56:
# page_content='. and probably helped me to get into the 21st century of doing things like this.Although the Lenovo ThinkTank t430 is a few years old now (it was originally loaded with Windows 7, but now has Windows 10), the Photoshop editing tools showed me that this laptop is more than capable of dealing with the latest, power intensive apps that is out there. I was impressed.' metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_2'}
#
# Chunk 57:
# page_content='Thanks it’s been working for now as I am just doing basic stuff and my grandkids love to watch the old dvds on it and it’s good to listen to my old cd collectionThanks' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 9 December 2023', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 58:
# page_content='Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker. I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 59:
# page_content='. I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device. Not a scratch, no wear on the keys, screen looks perfect and mint condition. Device was extremely clean and smelled fresh..' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_1'}
#
# Chunk 60:
# page_content='. I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc. Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office. Office was on there but a demo/online version where you then had to buy 365. I’m still a 2010 bloke so easily booted that up and all running really quickly' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_2'}
#
# Chunk 61:
# page_content='. In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_3'}
#
# Chunk 62:
# page_content='. Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage? For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_4'}
#
# Chunk 63:
# page_content='I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says)' metadata={'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_0'}
#
# Chunk 64:
# page_content='. Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend for a family member who may not be computer literate.' metadata={'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_1'}
#
# Chunk 65:
# page_content='Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.' metadata={'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified', 'chunk_id': 'ronan burke_0'}
#
# Chunk 66:
# page_content='This is a beautiful little laptop computer I am very pleased with it. My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem. Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included. I accepted and we received the PC in as new condition and very well packaged two days later' metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_0'}
#
# Chunk 67:
# page_content='. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.' metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 68:
# page_content="Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item." metadata={'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 69:
# page_content='Love my laptop works really well no issue' metadata={'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 70:
# page_content='Very good refurb, though the keyboard is USA configuration so get this checked out before buying if this is an issue. I found this out only after buying but the seller sorted the problem very quickly without affecting the warranty. This is a minor inconvenience as the £ sign is not readily available so if this is an issue just enquire before buying and get the seller to get a UK configured keyboard installed before shipping' metadata={'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._0'}
#
# Chunk 71:
# page_content='. Other than that the machine is fast, which is what I needed and for a refurb is in very good condition for the price. If you want something lighter and thinner this is not for you as the machine is sturdy and heavy but that is not a problem for me.' metadata={'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._1'}
#
# Chunk 72:
# page_content='One of the worst laptop purchase, it comes with a Super Slow processing with a factory and a heavy weight.... It would not allow you any experience of laptop but a box defective refurbished electronic item, not at all recommended, check reviews before purchasing....' metadata={'author': 'Pradeep Shokeen', 'rating': '1.0', 'title': '1.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 January 2024', 'verified': 'Not Verified', 'chunk_id': 'Pradeep Shokeen_0'}
#
# Chunk 73:
# page_content="I don't pretend to be a technophobe when it comes to computers so I will describe my user experience with the refurbished Lenovo ThinkTank T430.I think one of the biggest tests I could give it's computing power is by using the Photoshop image editing app, and it coped with the apps very well. The laptop loaded both lightroom and photoshop very quickly and the lag between me carrying out an edit on an image, and what appeared on the screen, was barely perceptible" metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_0'}
#
# Chunk 74:
# page_content=". I was also impressed with the speed photos were moved from lightroom into photoshop for further editing. Again, the speed was very quick, taking only a few seconds to open up photoshop and 'dump' the photo I wanted to edit into the photoshop app. I should point out that I was using the very latest Lightroom and Photoshop apps.With the SSD hard drive being so small in modern terms and no traditional hard drive to back it up, I have had to get used to using the cloud to store documents etc" metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_1'}
#
# Chunk 75:
# page_content='. and probably helped me to get into the 21st century of doing things like this.Although the Lenovo ThinkTank t430 is a few years old now (it was originally loaded with Windows 7, but now has Windows 10), the Photoshop editing tools showed me that this laptop is more than capable of dealing with the latest, power intensive apps that is out there. I was impressed.' metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_2'}
#
# Chunk 76:
# page_content='Thanks it’s been working for now as I am just doing basic stuff and my grandkids love to watch the old dvds on it and it’s good to listen to my old cd collectionThanks' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 9 December 2023', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 77:
# page_content='Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker. I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 78:
# page_content='. I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device. Not a scratch, no wear on the keys, screen looks perfect and mint condition. Device was extremely clean and smelled fresh..' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_1'}
#
# Chunk 79:
# page_content='. I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc. Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office. Office was on there but a demo/online version where you then had to buy 365. I’m still a 2010 bloke so easily booted that up and all running really quickly' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_2'}
#
# Chunk 80:
# page_content='. In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_3'}
#
# Chunk 81:
# page_content='. Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage? For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_4'}
#
# Chunk 82:
# page_content='I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says)' metadata={'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_0'}
#
# Chunk 83:
# page_content='. Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend for a family member who may not be computer literate.' metadata={'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_1'}
#
# Chunk 84:
# page_content='Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.' metadata={'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified', 'chunk_id': 'ronan burke_0'}
#
# Chunk 85:
# page_content='This is a beautiful little laptop computer I am very pleased with it. My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem. Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included. I accepted and we received the PC in as new condition and very well packaged two days later' metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_0'}
#
# Chunk 86:
# ...
#
# Chunk 352:
# page_content='. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.' metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 353:
# page_content="Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item." metadata={'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 354:
# page_content='Love my laptop works really well no issue' metadata={'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 355:
# page_content='Very good refurb, though the keyboard is USA configuration so get this checked out before buying if this is an issue. I found this out only after buying but the seller sorted the problem very quickly without affecting the warranty. This is a minor inconvenience as the £ sign is not readily available so if this is an issue just enquire before buying and get the seller to get a UK configured keyboard installed before shipping' metadata={'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._0'}
#
# Chunk 356:
# page_content='. Other than that the machine is fast, which is what I needed and for a refurb is in very good condition for the price. If you want something lighter and thinner this is not for you as the machine is sturdy and heavy but that is not a problem for me.' metadata={'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._1'}
#
# Chunk 357:
# page_content='One of the worst laptop purchase, it comes with a Super Slow processing with a factory and a heavy weight.... It would not allow you any experience of laptop but a box defective refurbished electronic item, not at all recommended, check reviews before purchasing....' metadata={'author': 'Pradeep Shokeen', 'rating': '1.0', 'title': '1.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 January 2024', 'verified': 'Not Verified', 'chunk_id': 'Pradeep Shokeen_0'}
#
# Chunk 358:
# page_content="I don't pretend to be a technophobe when it comes to computers so I will describe my user experience with the refurbished Lenovo ThinkTank T430.I think one of the biggest tests I could give it's computing power is by using the Photoshop image editing app, and it coped with the apps very well. The laptop loaded both lightroom and photoshop very quickly and the lag between me carrying out an edit on an image, and what appeared on the screen, was barely perceptible" metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_0'}
#
# Chunk 359:
# page_content=". I was also impressed with the speed photos were moved from lightroom into photoshop for further editing. Again, the speed was very quick, taking only a few seconds to open up photoshop and 'dump' the photo I wanted to edit into the photoshop app. I should point out that I was using the very latest Lightroom and Photoshop apps.With the SSD hard drive being so small in modern terms and no traditional hard drive to back it up, I have had to get used to using the cloud to store documents etc" metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_1'}
#
# Chunk 360:
# page_content='. and probably helped me to get into the 21st century of doing things like this.Although the Lenovo ThinkTank t430 is a few years old now (it was originally loaded with Windows 7, but now has Windows 10), the Photoshop editing tools showed me that this laptop is more than capable of dealing with the latest, power intensive apps that is out there. I was impressed.' metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_2'}
#
# Chunk 361:
# page_content='Thanks it’s been working for now as I am just doing basic stuff and my grandkids love to watch the old dvds on it and it’s good to listen to my old cd collectionThanks' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 9 December 2023', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 362:
# page_content='Just received the laptop two days ago so very early days as I haven’t given it a thorough test drive.However on face value, appears to be an excellent deal.Firstly the delivery process could have been slicker. I knew roughly delivery date - it was delivered bang on time by the way - but would have been great given the delivery details, tracker number etc' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}
#
# Chunk 363:
# page_content='. I chased this and was given day before delivery date - perhaps me being impatient and a very, very minor quibble.Laptop arrived in very secure packaging and, with the exception that the box was plain rather than Lenovo branded, you could easily be fooled this was a brand new device. Not a scratch, no wear on the keys, screen looks perfect and mint condition. Device was extremely clean and smelled fresh..' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_1'}
#
# Chunk 364:
# page_content='. I know odd comment but I guess it was wiped thoroughly with a citrus wipe or similar perhaps due to Covid19.On booting up, was really fast and had the advertised storage space, RAM etc. Perhaps this is me being IT illiterate but I had to load my own version of Microsoft Office. Office was on there but a demo/online version where you then had to buy 365. I’m still a 2010 bloke so easily booted that up and all running really quickly' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_2'}
#
# Chunk 365:
# page_content='. In fact there’s another version of office tools installed but I didn’t recognise the make - therefore could be a version already for those who don’t have Office already installed?!I’ve put 4 stars on battery as I’m uncertain if it is brand new but if original then this device is a few years old' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_3'}
#
# Chunk 366:
# page_content='. Therefore expecting a shorter battery life than a brand new battery but they can be easily, and relatively cheaply, replaced.What more can I say at this stage? For just under £240 for a very decent, solidly built ex-business model packed with 256 SSD, 16gb RAM and i5 processor is an absolute bargain and one I would definitely recommend!' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 March 2020', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_4'}
#
# Chunk 367:
# page_content='I was skeptical at first with it being a refurbishment but I’ve used Lenovo Thinkpads for work so I know they are a good unit. This is a really good buy for anyone who wants to do office work with a large amount of RAM and good speeds, whether work or educational it’s great. No issues with set up, windows keys worked with no problems. Has the ability to upgrade to windows 11 and couldn’t be happier with this product overall. Battery life is a good 3 and half hours (so it says)' metadata={'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_0'}
#
# Chunk 368:
# page_content='. Bought this because of the model and disk drive capabilities with lots of multimedia functions. It does weigh quite heavily, you should know that in case you were deciding to shoulder strap bag it on a big or commute. Overall great purchase, defo recommend for a family member who may not be computer literate.' metadata={'author': 'TheWoWMan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 30 December 2021', 'verified': 'Not Verified', 'chunk_id': 'TheWoWMan_1'}
#
# Chunk 369:
# page_content='Came next day (not a prime member) well wrapped arrived in great condition. Good value laptop. Easy to set up . Would recommend.' metadata={'author': 'ronan burke', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 7 October 2023', 'verified': 'Not Verified', 'chunk_id': 'ronan burke_0'}
#
# Chunk 370:
# page_content='This is a beautiful little laptop computer I am very pleased with it. My husband bought it for me to replace an old Lenovo I had had since 2014 and Windows 8 support was being withdrawn. I was not sure about Windows 10 but it is no problem. Prior to despatch the seller very kindly offered an upgrade free of charge but including all the things the original order included. I accepted and we received the PC in as new condition and very well packaged two days later' metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_0'}
#
# Chunk 371:
# page_content='. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.' metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}
#
# Chunk 372:
# page_content="Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item." metadata={'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}
#
# Chunk 373:
# page_content='Love my laptop works really well no issue' metadata={'author': 'PHILIPPE LEFEUVRE', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 10 February 2024', 'verified': 'Not Verified', 'chunk_id': 'PHILIPPE LEFEUVRE_0'}
#
# Chunk 374:
# page_content='Very good refurb, though the keyboard is USA configuration so get this checked out before buying if this is an issue. I found this out only after buying but the seller sorted the problem very quickly without affecting the warranty. This is a minor inconvenience as the £ sign is not readily available so if this is an issue just enquire before buying and get the seller to get a UK configured keyboard installed before shipping' metadata={'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._0'}
#
# Chunk 375:
# page_content='. Other than that the machine is fast, which is what I needed and for a refurb is in very good condition for the price. If you want something lighter and thinner this is not for you as the machine is sturdy and heavy but that is not a problem for me.' metadata={'author': 'J.', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 26 August 2021', 'verified': 'Not Verified', 'chunk_id': 'J._1'}
#
# Chunk 376:
# page_content='One of the worst laptop purchase, it comes with a Super Slow processing with a factory and a heavy weight.... It would not allow you any experience of laptop but a box defective refurbished electronic item, not at all recommended, check reviews before purchasing....' metadata={'author': 'Pradeep Shokeen', 'rating': '1.0', 'title': '1.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 20 January 2024', 'verified': 'Not Verified', 'chunk_id': 'Pradeep Shokeen_0'}
#
# Chunk 377:
# page_content="I don't pretend to be a technophobe when it comes to computers so I will describe my user experience with the refurbished Lenovo ThinkTank T430.I think one of the biggest tests I could give it's computing power is by using the Photoshop image editing app, and it coped with the apps very well. The laptop loaded both lightroom and photoshop very quickly and the lag between me carrying out an edit on an image, and what appeared on the screen, was barely perceptible" metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_0'}
#
# Chunk 378:
# page_content=". I was also impressed with the speed photos were moved from lightroom into photoshop for further editing. Again, the speed was very quick, taking only a few seconds to open up photoshop and 'dump' the photo I wanted to edit into the photoshop app. I should point out that I was using the very latest Lightroom and Photoshop apps.With the SSD hard drive being so small in modern terms and no traditional hard drive to back it up, I have had to get used to using the cloud to store documents etc" metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_1'}
#
# Chunk 379:
# page_content='. and probably helped me to get into the 21st century of doing things like this.Although the Lenovo ThinkTank t430 is a few years old now (it was originally loaded with Windows 7, but now has Windows 10), the Photoshop editing tools showed me that this laptop is more than capable of dealing with the latest, power intensive apps that is out there. I was impressed.' metadata={'author': 'Peter.S', 'rating': '4.0', 'title': '4.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 14 August 2019', 'verified': 'Not Verified', 'chunk_id': 'Peter.S_2'}
#
# Chunk 380:
# page_content='Thanks it’s been working for now as I am just doing basic stuff and my grandkids love to watch the old dvds on it and it’s good to listen to my old cd collectionThanks' metadata={'author': 'Amazon Customer', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 9 December 2023', 'verified': 'Not Verified', 'chunk_id': 'Amazon Customer_0'}

# %% [markdown]
# # Load documents into FAISS vector store

# %%
# !pip install -q -U faiss-cpu tiktoken sentence-transformers

# %%
pip install -U langchain-community
# Out:
# Collecting langchain-community
#   Downloading langchain_community-0.2.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Requirement already satisfied: langchain<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.2.1)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.2.3)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.67)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.21.2-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 7.7 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain-community) (0.2.0)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain-community) (2.7.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community) (1.33)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.0->langchain-community) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2024.2.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain-community) (2.4)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain-community) (2.18.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, marshmallow, typing-inspect, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.6 langchain-community-0.2.1 marshmallow-3.21.2 mypy-extensions-1.0.0 typing-inspect-0.9.0

# %%
from langchain.embeddings import CacheBackedEmbeddings, HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.storage import LocalFileStore

store = LocalFileStore("./cache/")
embed_model_id = 'sentence-transformers/all-MiniLM-L6-v2'

core_embeddings_model = HuggingFaceEmbeddings(
    model_name=embed_model_id
)

embedder = CacheBackedEmbeddings.from_bytes_store(
    core_embeddings_model, store, namespace=embed_model_id
)

vector_store = FAISS.from_documents(documents, embedder)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# # Alternative embedding using page content + metadata

# %%
from langchain.embeddings import CacheBackedEmbeddings, HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.storage import LocalFileStore

store = LocalFileStore("./cache/")
embed_model_id = 'sentence-transformers/all-MiniLM-L6-v2'

class CustomHuggingFaceEmbeddings(HuggingFaceEmbeddings):
    def embed(self, documents):
        embeddings = []
        for doc in documents:
            # Combine text content and metadata
            content = doc['page_content']
            metadata = doc['metadata']
            chunk_id = metadata.get('chunk_id','')
            combined_text = f"{content} {chunk_id}"  # Adjust as needed

            # Generate embeddings for combined text
            embedding = super().embed(combined_text)
            embeddings.append(embedding)
        return embeddings

core_embeddings_model = CustomHuggingFaceEmbeddings(
    model_name=embed_model_id
)

embedder = CacheBackedEmbeddings.from_bytes_store(
    core_embeddings_model, store, namespace=embed_model_id
)

vector_store = FAISS.from_documents(documents, embedder)

# %% [markdown]
# # Check if vector store works with a query

# %%
def retrieve_unique_chunks(query, vector_store, core_embeddings_model, k):
    embedding_vector = core_embeddings_model.embed_query(query)
    docs = vector_store.similarity_search_by_vector(embedding_vector, k )  # Retrieve more to filter later

    unique_chunks = []
    seen_chunk_ids = set()
    for doc in docs:
        if doc.metadata["chunk_id"] not in seen_chunk_ids:
            unique_chunks.append(doc)
            seen_chunk_ids.add(doc.metadata["chunk_id"])
        if len(unique_chunks) == k:
            break
    return unique_chunks

# Example usage
query = "What processor does the computer have?"
top_k_chunks = retrieve_unique_chunks(query, vector_store, core_embeddings_model, k=4)

for i, page in enumerate(top_k_chunks):
    print(f"Unique Chunk {i+1}:\n{page.page_content}\nMetadata: {page.metadata}\n")
# Out:
# Unique Chunk 1:
# Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item.
# Metadata: {'author': 'AbsoAbsolutely rubbish', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 1 May 2024', 'verified': 'Not Verified', 'chunk_id': 'AbsoAbsolutely rubbish_0'}

# %%
query = "How is the performance of this computer?"
embedding_vector = core_embeddings_model.embed_query(query)
docs = vector_store.similarity_search_by_vector(embedding_vector, k = 4)

for page in docs:
  print(page.page_content)
# Out:
# Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item.
# Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item.
# Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item.
# Absolutely Amazing Laptop and with an i5 processor,Great hard drive capacity and I'm very pleased with this well priced item.

# %% [markdown]
# # Build Retrival chain

# %%
# !pip install -q -U transformers huggingface_hub torch

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import torch
import transformers

model_id = "meta-llama/Llama-2-13b-chat-hf"

bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type='nf4',
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16
)

model_config = transformers.AutoConfig.from_pretrained(
    model_id
)

model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    config=model_config,
    quantization_config=bnb_config,
    device_map='auto'
)

model.eval()
# Need to save the model to avoid downloading it
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-41f6e423ba5f> in <cell line: 17>()
#      15 )
#      16
# ---> 17 model = transformers.AutoModelForCausalLM.from_pretrained(
#      18     model_id,
#      19     trust_remote_code=True,
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     561         elif type(config) in cls._model_mapping.keys():
#     562             model_class = _get_model_class(config, cls._model_mapping)
# --> 563             return model_class.from_pretrained(
#     564                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     565             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3701
#    3702             if hf_quantizer is not None:
# -> 3703                 hf_quantizer.validate_environment(device_map=device_map)
#    3704
#    3705         elif device_map is not None:
#
# /usr/local/lib/python3.10/dist-packages/transformers/quantizers/quantizer_bnb_4bit.py in validate_environment(self, *args, **kwargs)
#      83             }
#      84             if "cpu" in device_map_without_lm_head.values() or "disk" in device_map_without_lm_head.values():
# ---> 85                 raise ValueError(
#      86                     "Some modules are dispatched on the CPU or the disk. Make sure you have enough GPU RAM to fit the "
#      87                     "quantized model. If you want to dispatch the model on the CPU or the disk while keeping these modules "
#
# ValueError: Some modules are dispatched on the CPU or the disk. Make sure you have enough GPU RAM to fit the quantized model. If you want to dispatch the model on the CPU or the disk while keeping these modules in 32-bit, you need to set `load_in_8bit_fp32_cpu_offload=True` and pass a custom `device_map` to `from_pretrained`. Check https://huggingface.co/docs/transformers/main/en/main_classes/quantization#offload-between-cpu-and-gpu for more details.

# %% [markdown]
# #Tokenizer

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained(
    model_id
)

# %% [markdown]
# #Pack it into a pipeline for compatibility with LangChain

# %%
generate_text = transformers.pipeline(
    model=model,
    tokenizer=tokenizer,
    task="text-generation",
    return_full_text=True,
    temperature=0.2,
    max_new_tokens=256
)

# %%
from langchain.llms import HuggingFacePipeline

llm = HuggingFacePipeline(pipeline=generate_text)

# %%
retriever = vector_store.as_retriever()

# %%
from langchain.chains import RetrievalQA
from langchain.callbacks import StdOutCallbackHandler

handler = StdOutCallbackHandler()

qa_with_sources_chain = RetrievalQA.from_chain_type(
    llm=llm,
    retriever=retriever,
    callbacks=[handler],
    return_source_documents=True
)

# %% [markdown]
# # Tests

# %%
qa_with_sources_chain({"query" : "Is this computer cheap?"})
# Out:
# > Entering new RetrievalQA chain...
#
# > Finished chain.
# {'query': 'Is this computer cheap?',
#  'result': "Use the following pieces of context to answer the question at the end. If you don't know the answer, just say that you don't know, don't try to make up an answer.\n\n. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.\n\n. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.\n\n. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.\n\n. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.\n\nQuestion: Is this computer cheap?\nHelpful Answer: Based on the information provided, it seems that the computer is not cheap. The fact that it is in excellent condition, has a fast processor, and has a high-quality keyboard suggests that it is a high-end computer. Additionally, the sellers have high standards of customer care and highly recommend the computer, which suggests that it is a reliable and trustworthy product. Overall, it does not seem that the computer is cheap, but rather a high-quality and reliable option.",
#  'source_documents': [Document(page_content='. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.', metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}),
#   Document(page_content='. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.', metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}),
#   Document(page_content='. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.', metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'}),
#   Document(page_content='. The computer is very compact and is in excellent to nearly new condition. I am having to get used to a smaller keyboard but that also is no problem. The computer is also a lot faster than my old one, especially booting up and shutting down. I have to say that the sellers also have very high standards of customer care and highly recommend anyone looking to buy a computer to buy from them.', metadata={'author': 'Susan', 'rating': '5.0', 'title': '5.0 out of 5 stars', 'date': 'Reviewed in the United Kingdom on 19 January 2023', 'verified': 'Not Verified', 'chunk_id': 'Susan_1'})]}
